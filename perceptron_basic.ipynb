# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Abhinav Mishra\Downloads\placement (1).csv")

print(df.shape)
print(df.head())
# Out:
# (100, 3)
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
sns.scatterplot(
    x=df['cgpa'],
    y=df['resume_score'],
    hue=df['placed']
)
X = df.iloc[:,0:2]
y = df.iloc[:,-1]
 
from sklearn.linear_model import Perceptron
p = Perceptron()
p.fit(X,y)
Perceptron()
p.coef_

p.intercept_

from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X.values, y.values, clf=p, legend=2)
# Out:
# C:\Users\Abhinav Mishra\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   equal length arrays, then the output is a 2D numpy.array.
# <Axes: xlabel='cgpa', ylabel='resume_score'>
